# %%
# Import necessary libraries
import cv2
from ultralytics import YOLO

# Load the trained YOLOv8 model

model = YOLO("best.pt")

# %%
# Initialize the video capture for the MP4 video
cap = cv2.VideoCapture("testvideo.mp4") # Add the path to video here

# %%
# Function to process each frame
def process_frame(frame):
    # Reduce the size of the frame for faster processing
    resized_frame = cv2.resize(frame, (640, 480))
    
    # Run YOLOv8 inference on the frame
    results = model(resized_frame)
    
    # Draw the results on the frame
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()  # xyxy (N, 4)
        confs = result.boxes.conf.cpu().numpy()  # (N,)
        class_ids = result.boxes.cls.cpu().numpy()  # (N,)
        for box, conf, class_id in zip(boxes, confs, class_ids):
            x1, y1, x2, y2 = map(int, box)
            label = model.names[int(class_id)]  # Get the class name
            cv2.rectangle(resized_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(resized_frame, f'{label} {conf:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return resized_frame

# %%
# Process the video and display the results
import time

try:
    frame_skip = 5  # Process every 2nd frame to reduce load
    frame_count = 0
    
    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        if frame_count % frame_skip != 0:
            continue
        
        # Process the frame
        start_time = time.time()
        processed_frame = process_frame(frame)
        end_time = time.time()
        
        # Calculate and display the frame processing time
        fps = 1 / (end_time - start_time)
        cv2.putText(processed_frame, f'FPS: {fps:.2f}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        
        # Display the resulting frame
        cv2.imshow('YOLOv8 Video Test', processed_frame)
        
        # Break the loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:
    # Release the video capture and close windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 1440x1920 (no detections), 1140.5ms
# Speed: 39.5ms preprocess, 1140.5ms inference, 16.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1028.0ms
# Speed: 38.0ms preprocess, 1028.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 978.4ms
# Speed: 18.7ms preprocess, 978.4ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 966.8ms
# Speed: 21.0ms preprocess, 966.8ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 984.1ms
# Speed: 20.7ms preprocess, 984.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 969.8ms
# Speed: 19.2ms preprocess, 969.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 972.2ms
# Speed: 19.0ms preprocess, 972.2ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1000.7ms
# Speed: 18.6ms preprocess, 1000.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
# 2024-07-17 01:35:52.619 Python[14613:6768094] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_attributesForCharacterIndex:reply:) block performed very slowly (1.05 secs).
# 0: 1440x1920 (no detections), 986.0ms
# Speed: 19.0ms preprocess, 986.0ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 981.4ms
# Speed: 19.1ms preprocess, 981.4ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 996.6ms
# Speed: 19.4ms preprocess, 996.6ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 978.1ms
# Speed: 18.9ms preprocess, 978.1ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920
ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 920.0ms
# Speed: 19.3ms preprocess, 920.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 926.9ms
# Speed: 18.7ms preprocess, 926.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 928.7ms
# Speed: 19.6ms preprocess, 928.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 922.6ms
# Speed: 18.3ms preprocess, 922.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 943.1ms
# Speed: 18.8ms preprocess, 943.1ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 932.3ms
# Speed: 18.4ms preprocess, 932.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Safety Vests, 930.2ms
# Speed: 20.7ms preprocess, 930.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Safety Vests, 926.7ms
# Speed: 18.8ms preprocess, 926.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Safety Vests, 933.9ms
# Speed: 18.8ms preprocess, 933.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Glove, 2 Safety Vests, 927.7ms
# Speed: 19.0ms preprocess, 927.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Glasses, 2 Safety Vests, 934.6ms
# Speed: 19.1ms preprocess, 934.6ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Glasses, 1 Safety Vest, 928.0ms
# Speed: 19.0ms preprocess, 928.0ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Glasses, 1 Safety Vest, 936.1ms
# Speed: 18.4ms preprocess, 936.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Glasses, 1 Safety Vest, 927.5ms
# Speed: 18.9ms preprocess, 927.5ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 1 Safety Glasses, 1 Safety Vest, 941.8ms
# Speed: 18.9ms preprocess, 941.8ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 1 Safety Vest, 931.7ms
# Speed: 18.5ms preprocess, 931.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Safety Vests, 935.9ms
# Speed: 18.8ms preprocess, 935.9ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Safety Vests, 923.9ms
# Speed: 18.3ms preprocess, 923.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 923.9ms
# Speed: 19.0ms preprocess, 923.9ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 928.3ms
# Speed: 19.3ms preprocess, 928.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 923.8ms
# Speed: 18.7ms preprocess, 923.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 928.3ms
# Speed: 18.9ms preprocess, 928.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 933.4ms
# Speed: 18.3ms preprocess, 933.4ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Vest, 940.3ms
# Speed: 19.0ms preprocess, 940.3ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Vest, 919.2ms
# Speed: 18.7ms preprocess, 919.2ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Vest, 945.7ms
# Speed: 18.9ms preprocess, 945.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Glasses, 1 Safety Vest, 932.7ms
# Speed: 18.9ms preprocess, 932.7ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Mask, 1 Person, 1 Safety Glasses, 1 Safety Vest, 941.8ms
# Speed: 19.3ms preprocess, 941.8ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 NO-Safety Vest, 1 Person, 1 Safety Glasses, 1 Safety Vest, 921.4ms
# Speed: 18.3ms preprocess, 921.4ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 NO-Safety Vest, 1 Person, 930.9ms
# Speed: 18.7ms preprocess, 930.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Vest, 918.3ms
# Speed: 19.1ms preprocess, 918.3ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 1 Safety Vest, 997.8ms
# Speed: 18.7ms preprocess, 997.8ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 1 Safety Vest, 994.6ms
# Speed: 18.1ms preprocess, 994.6ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 No-Mask, 1 Safety Vest, 976.9ms
# Speed: 18.9ms preprocess, 976.9ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Mask, 1 Safety Glasses, 1 Safety Vest, 931.4ms
# Speed: 18.4ms preprocess, 931.4ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Mask, 1 Safety Glasses, 1 Safety Vest, 1058.0ms
# Speed: 19.1ms preprocess, 1058.0ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Mask, 1 Safety Glasses, 1 Safety Vest, 1073.8ms
# Speed: 20.5ms preprocess, 1073.8ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Vest, 1048.2ms
# Speed: 21.6ms preprocess, 1048.2ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Mask, 1 Person, 1 Safety Vest, 1022.6ms
# Speed: 19.2ms preprocess, 1022.6ms inference, 2.4ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Vest, 1002.8ms
# Speed: 19.5ms preprocess, 1002.8ms inference, 2.5ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1012.7ms
# Speed: 18.5ms preprocess, 1012.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1035.7ms
# Speed: 18.9ms preprocess, 1035.7ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 996.1ms
# Speed: 19.1ms preprocess, 996.1ms inference, 2.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1026.4ms
# Speed: 19.3ms preprocess, 1026.4ms inference, 2.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1023.3ms
# Speed: 21.6ms preprocess, 1023.3ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1012.9ms
# Speed: 19.7ms preprocess, 1012.9ms inference, 2.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1034.2ms
# Speed: 19.0ms preprocess, 1034.2ms inference, 2.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 977.3ms
# Speed: 21.4ms preprocess, 977.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 968.7ms
# Speed: 19.2ms preprocess, 968.7ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1034.7ms
# Speed: 18.4ms preprocess, 1034.7ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1044.9ms
# Speed: 25.1ms preprocess, 1044.9ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1053.3ms
# Speed: 18.7ms preprocess, 1053.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1032.3ms
# Speed: 18.8ms preprocess, 1032.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1035.4ms
# Speed: 18.9ms preprocess, 1035.4ms inference, 2.3ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 1011.6ms
# Speed: 19.1ms preprocess, 1011.6ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 934.7ms
# Speed: 19.5ms preprocess, 934.7ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 935.3ms
# Speed: 18.5ms preprocess, 935.3ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 923.9ms
# Speed: 19.0ms preprocess, 923.9ms inference, 1.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 927.1ms
# Speed: 19.1ms preprocess, 927.1ms inference, 2.0ms postprocess per image at shape (1, 3, 1440, 1920)

# %%
# Release the video capture and close windows if not already done
cap.release()
cv2.destroyAllWindows()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
