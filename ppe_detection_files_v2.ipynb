# %% [markdown]
# # PPE Equipment Detection - v2

# %%
# Import necessary libraries
import cv2
from ultralytics import YOLO

# Load the trained YOLOv8 model

model = YOLO("model/best_version_3.pt") # Choose the model here

# %%
# Initialize the video capture for the MP4 video
cap = cv2.VideoCapture("files_detection/videos/workers_1.mp4") # Add the path to video here

# %%
# Function to process each frame
def process_frame(frame):
    # Reduce the size of the frame for faster processing
    resized_frame = cv2.resize(frame, (640, 480))
    
    # Run YOLOv8 inference on the frame
    results = model(resized_frame)
    
    # Draw the results on the frame
    for result in results:
        boxes = result.boxes.xyxy.cpu().numpy()  # xyxy (N, 4)
        confs = result.boxes.conf.cpu().numpy()  # (N,)
        class_ids = result.boxes.cls.cpu().numpy()  # (N,)
        for box, conf, class_id in zip(boxes, confs, class_ids):
            x1, y1, x2, y2 = map(int, box)
            label = model.names[int(class_id)]  # Get the class name
            cv2.rectangle(resized_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(resized_frame, f'{label} {conf:.2f}', (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return resized_frame

# %%
# Process the video and display the results
import time

try:
    frame_skip = 5  # Process every 2nd frame to reduce load
    frame_count = 0
    
    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        if frame_count % frame_skip != 0:
            continue
        
        # Process the frame
        start_time = time.time()
        processed_frame = process_frame(frame)
        end_time = time.time()
        
        # Calculate and display the frame processing time
        fps = 1 / (end_time - start_time)
        cv2.putText(processed_frame, f'FPS: {fps:.2f}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
        
        # Display the resulting frame
        cv2.imshow('YOLOv8 Video Test', processed_frame)
        
        # Break the loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
finally:
    # Release the video capture and close windows
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 1440x1920 2 Helmets, 1 No-Glove, 3 Safety Vests, 710.7ms
# Speed: 20.7ms preprocess, 710.7ms inference, 6.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Glove, 3 Safety Vests, 703.0ms
# Speed: 13.1ms preprocess, 703.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Glove, 3 Safety Vests, 634.4ms
# Speed: 11.8ms preprocess, 634.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 630.0ms
# Speed: 11.6ms preprocess, 630.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 631.4ms
# Speed: 13.5ms preprocess, 631.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 627.9ms
# Speed: 11.6ms preprocess, 627.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 627.7ms
# Speed: 11.9ms preprocess, 627.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 633.2ms
# Speed: 11.6ms preprocess, 633.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 622.2ms
# Speed: 12.2ms preprocess, 622.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 623.9ms
# Speed: 11.4ms preprocess, 623.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 630.5ms
# Speed: 12.0ms preprocess, 630.5ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 3 Safety Vests, 629.2ms
# Speed: 11.9ms preprocess, 629.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 2 Safety Vests, 623.9ms
# Speed: 12.2ms preprocess, 623.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Mask, 1 No-Glasses, 2 Safety Vests, 626.4ms
# Speed: 11.7ms preprocess, 626.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 2 Safety Vests, 637.7ms
# Speed: 12.0ms preprocess, 637.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Masks, 2 Safety Vests, 634.9ms
# Speed: 11.7ms preprocess, 634.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 648.5ms
# Speed: 11.9ms preprocess, 648.5ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 666.5ms
# Speed: 14.7ms preprocess, 666.5ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 2 Safety Vests, 634.1ms
# Speed: 12.5ms preprocess, 634.1ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Mask, 1 Safety Vest, 636.9ms
# Speed: 12.7ms preprocess, 636.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 633.4ms
# Speed: 12.4ms preprocess, 633.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 627.0ms
# Speed: 12.2ms preprocess, 627.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 5 Safety Vests, 635.3ms
# Speed: 12.5ms preprocess, 635.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 643.3ms
# Speed: 12.0ms preprocess, 643.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 649.1ms
# Speed: 12.1ms preprocess, 649.1ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 4 Safety Vests, 658.7ms
# Speed: 12.4ms preprocess, 658.7ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 4 Safety Vests, 643.3ms
# Speed: 13.2ms preprocess, 643.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 No-Glove, 3 Safety Vests, 676.6ms
# Speed: 13.0ms preprocess, 676.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 631.7ms
# Speed: 12.7ms preprocess, 631.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 No-Glove, 3 Safety Vests, 660.2ms
# Speed: 12.3ms preprocess, 660.2ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Masks, 1 No-Glove, 3 Safety Vests, 637.2ms
# Speed: 12.3ms preprocess, 637.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 4 Masks, 1 Person, 2 Safety Vests, 621.7ms
# Speed: 11.7ms preprocess, 621.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 4 Masks, 2 Safety Vests, 635.4ms
# Speed: 12.1ms preprocess, 635.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 3 Masks, 2 Safety Vests, 636.8ms
# Speed: 12.2ms preprocess, 636.8ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Person, 2 Safety Vests, 627.5ms
# Speed: 12.3ms preprocess, 627.5ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 5 Safety Vests, 631.9ms
# Speed: 11.6ms preprocess, 631.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Safety Vests, 624.3ms
# Speed: 12.0ms preprocess, 624.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 4 Safety Vests, 626.7ms
# Speed: 11.8ms preprocess, 626.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 4 Safety Vests, 630.6ms
# Speed: 11.8ms preprocess, 630.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 4 Safety Vests, 621.4ms
# Speed: 11.5ms preprocess, 621.4ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 4 Safety Vests, 625.9ms
# Speed: 11.7ms preprocess, 625.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 4 Safety Vests, 635.3ms
# Speed: 12.1ms preprocess, 635.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 3 Safety Vests, 625.9ms
# Speed: 12.0ms preprocess, 625.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 4 Safety Vests, 628.4ms
# Speed: 11.8ms preprocess, 628.4ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 4 Safety Vests, 641.9ms
# Speed: 12.2ms preprocess, 641.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 4 Safety Vests, 646.9ms
# Speed: 12.1ms preprocess, 646.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 4 Safety Vests, 643.1ms
# Speed: 12.1ms preprocess, 643.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Masks, 1 Safety Vest, 639.2ms
# Speed: 11.4ms preprocess, 639.2ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 2 Safety Vests, 628.9ms
# Speed: 11.5ms preprocess, 628.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 3 Safety Vests, 641.4ms
# Speed: 12.5ms preprocess, 641.4ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 2 Safety Vests, 637.3ms
# Speed: 11.5ms preprocess, 637.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 629.5ms
# Speed: 12.6ms preprocess, 629.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 3 Safety Vests, 657.2ms
# Speed: 12.5ms preprocess, 657.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Safety Vests, 648.2ms
# Speed: 12.5ms preprocess, 648.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 3 Safety Vests, 654.9ms
# Speed: 12.3ms preprocess, 654.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Person, 4 Safety Vests, 631.6ms
# Speed: 11.7ms preprocess, 631.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Person, 3 Safety Vests, 632.0ms
# Speed: 12.1ms preprocess, 632.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Safety Vest, 629.8ms
# Speed: 11.7ms preprocess, 629.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 2 Safety Vests, 634.8ms
# Speed: 12.0ms preprocess, 634.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 3 Safety Vests, 649.1ms
# Speed: 12.2ms preprocess, 649.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 2 Safety Vests, 636.7ms
# Speed: 11.8ms preprocess, 636.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Vest, 625.1ms
# Speed: 12.3ms preprocess, 625.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 627.5ms
# Speed: 11.7ms preprocess, 627.5ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 3 Safety Vests, 629.7ms
# Speed: 12.0ms preprocess, 629.7ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 620.7ms
# Speed: 12.0ms preprocess, 620.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 3 Safety Vests, 630.7ms
# Speed: 11.7ms preprocess, 630.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 3 Safety Vests, 636.1ms
# Speed: 13.1ms preprocess, 636.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 4 Safety Vests, 634.9ms
# Speed: 11.6ms preprocess, 634.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 2 Safety Vests, 631.9ms
# Speed: 11.5ms preprocess, 631.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 2 Safety Vests, 646.1ms
# Speed: 12.2ms preprocess, 646.1ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 2 Safety Vests, 627.0ms
# Speed: 11.5ms preprocess, 627.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 3 Safety Vests, 633.7ms
# Speed: 11.5ms preprocess, 633.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 5 Safety Vests, 647.3ms
# Speed: 11.5ms preprocess, 647.3ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 4 Safety Vests, 638.7ms
# Speed: 11.7ms preprocess, 638.7ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Mask, 4 Safety Vests, 631.7ms
# Speed: 11.6ms preprocess, 631.7ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Masks, 4 Safety Vests, 644.0ms
# Speed: 11.6ms preprocess, 644.0ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 2 Safety Vests, 632.1ms
# Speed: 12.5ms preprocess, 632.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Person, 3 Safety Vests, 634.3ms
# Speed: 11.9ms preprocess, 634.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 632.3ms
# Speed: 11.6ms preprocess, 632.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Mask, 1 Safety Glasses, 3 Safety Vests, 633.8ms
# Speed: 11.4ms preprocess, 633.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Safety Vest, 638.9ms
# Speed: 12.2ms preprocess, 638.9ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Safety Vest, 653.4ms
# Speed: 12.8ms preprocess, 653.4ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 No-Glove, 1 Safety Vest, 642.9ms
# Speed: 12.0ms preprocess, 642.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 No-Glove, 1 Safety Glasses, 1 Safety Vest, 632.3ms
# Speed: 11.5ms preprocess, 632.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 No-Glove, 1 Safety Vest, 656.8ms
# Speed: 12.2ms preprocess, 656.8ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 No-Glove, 1 Safety Glasses, 1 Safety Vest, 632.3ms
# Speed: 12.8ms preprocess, 632.3ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 NO-Safety Vest, 1 Safety Glasses, 1 Safety Vest, 623.7ms
# Speed: 11.3ms preprocess, 623.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Safety Glasses, 639.8ms
# Speed: 12.2ms preprocess, 639.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Glasses, 1 Safety Vest, 637.6ms
# Speed: 12.9ms preprocess, 637.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Safety Vest, 630.4ms
# Speed: 11.5ms preprocess, 630.4ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 1 No-Glove, 1 Safety Glasses, 1 Safety Vest, 642.1ms
# Speed: 13.2ms preprocess, 642.1ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Vest, 694.1ms
# Speed: 12.6ms preprocess, 694.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Safety Vest, 669.8ms
# Speed: 11.7ms preprocess, 669.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 No-Glove, 3 Safety Vests, 642.7ms
# Speed: 12.2ms preprocess, 642.7ms inference, 1.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 2 Safety Vests, 617.2ms
# Speed: 12.2ms preprocess, 617.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 1 Person, 1 Safety Glasses, 3 Safety Vests, 624.7ms
# Speed: 11.6ms preprocess, 624.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 Person, 3 Safety Vests, 619.6ms
# Speed: 12.8ms preprocess, 619.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 Person, 5 Safety Vests, 627.4ms
# Speed: 11.8ms preprocess, 627.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 5 Safety Vests, 624.1ms
# Speed: 11.8ms preprocess, 624.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 3 Safety Vests, 636.2ms
# Speed: 11.9ms preprocess, 636.2ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 2 Safety Vests, 627.4ms
# Speed: 12.2ms preprocess, 627.4ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Gloves, 2 Helmets, 1 Mask, 1 Safety Glasses, 2 Safety Vests, 627.6ms
# Speed: 12.5ms preprocess, 627.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 Safety Glasses, 2 Safety Vests, 632.3ms
# Speed: 12.1ms preprocess, 632.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 623.1ms
# Speed: 11.5ms preprocess, 623.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Safety Glasses, 1 Safety Vest, 628.8ms
# Speed: 12.5ms preprocess, 628.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 (no detections), 632.2ms
# Speed: 12.3ms preprocess, 632.2ms inference, 0.5ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Safety Vest, 630.8ms
# Speed: 12.0ms preprocess, 630.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 1 NO-Safety Vest, 1 Safety Vest, 608.9ms
# Speed: 11.6ms preprocess, 608.9ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 NO-Safety Vest, 635.1ms
# Speed: 11.6ms preprocess, 635.1ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 1 NO-Safety Vest, 625.5ms
# Speed: 11.5ms preprocess, 625.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 NO-Safety Vest, 635.1ms
# Speed: 12.0ms preprocess, 635.1ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 NO-Safety Vest, 2 Safety Vests, 632.2ms
# Speed: 11.5ms preprocess, 632.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 NO-Safety Vest, 2 Safety Vests, 631.5ms
# Speed: 13.2ms preprocess, 631.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 NO-Safety Vest, 2 Safety Vests, 612.4ms
# Speed: 12.4ms preprocess, 612.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Masks, 1 NO-Safety Vest, 1 Person, 2 Safety Vests, 615.5ms
# Speed: 12.0ms preprocess, 615.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 NO-Safety Vest, 1 No-Glove, 1 Person, 2 Safety Vests, 626.2ms
# Speed: 11.4ms preprocess, 626.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 Person, 2 Safety Vests, 620.3ms
# Speed: 11.6ms preprocess, 620.3ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Masks, 1 NO-Safety Vest, 1 No-Glove, 1 Person, 1 Safety Vest, 623.4ms
# Speed: 12.1ms preprocess, 623.4ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 1 Person, 1 Safety Vest, 631.5ms
# Speed: 12.2ms preprocess, 631.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 2 Masks, 1 No-Glove, 1 Person, 1 Safety Vest, 628.2ms
# Speed: 12.7ms preprocess, 628.2ms inference, 0.6ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Gloves, 2 Helmets, 2 Masks, 1 Person, 2 Safety Vests, 626.6ms
# Speed: 11.8ms preprocess, 626.6ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 1 NO-Safety Vest, 1 Person, 2 Safety Vests, 639.2ms
# Speed: 12.0ms preprocess, 639.2ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 1 NO-Safety Vest, 1 Person, 1 Safety Vest, 632.0ms
# Speed: 11.3ms preprocess, 632.0ms inference, 1.0ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 1 NO-Safety Vest, 1 Person, 1 Safety Glasses, 1 Safety Vest, 632.9ms
# Speed: 12.0ms preprocess, 632.9ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Masks, 1 NO-Safety Vest, 1 Person, 1 Safety Glasses, 1 Safety Vest, 628.3ms
# Speed: 12.2ms preprocess, 628.3ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Mask, 1 NO-Safety Vest, 1 Person, 1 Safety Glasses, 2 Safety Vests, 623.0ms
# Speed: 11.6ms preprocess, 623.0ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 3 Masks, 1 NO-Safety Vest, 1 No-Glove, 1 Person, 1 Safety Glasses, 2 Safety Vests, 622.2ms
# Speed: 12.1ms preprocess, 622.2ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Gloves, 2 Helmets, 3 Masks, 1 NO-Safety Vest, 1 Person, 1 Safety Glasses, 2 Safety Vests, 624.5ms
# Speed: 11.6ms preprocess, 624.5ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 2 Masks, 1 NO-Safety Vest, 1 Person, 1 Safety Vest, 645.6ms
# Speed: 12.2ms preprocess, 645.6ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 1 NO-Safety Vest, 1 Safety Vest, 640.8ms
# Speed: 12.6ms preprocess, 640.8ms inference, 0.8ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 1 Person, 1 Safety Vest, 650.8ms
# Speed: 12.1ms preprocess, 650.8ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 1 Helmet, 1 Mask, 3 Safety Vests, 627.7ms
# Speed: 12.0ms preprocess, 627.7ms inference, 0.7ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 1 Mask, 2 Safety Vests, 623.8ms
# Speed: 11.6ms preprocess, 623.8ms inference, 1.1ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 3 Safety Vests, 636.2ms
# Speed: 12.2ms preprocess, 636.2ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 2 Helmets, 2 Masks, 1 Person, 2 Safety Vests, 643.0ms
# Speed: 12.3ms preprocess, 643.0ms inference, 1.2ms postprocess per image at shape (1, 3, 1440, 1920)
#
# 0: 1440x1920 3 Helmets, 1 Mask, 1 No-Glove, 2 Safety Vests, 637.2ms
# Speed: 12.5ms preprocess, 637.2ms inference, 0.9ms postprocess per image at shape (1, 3, 1440, 1920)

# %%
# Release the video capture and close windows if not already done
cap.release()
cv2.destroyAllWindows()
